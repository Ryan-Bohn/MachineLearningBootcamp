# %% [markdown]
# ##Questions

# %% [markdown]
# ###Numbers

# %% [markdown]
# If you add an integer to a float, what is the output of the type?

# %%
type(4 + 0.5)
# Out:
# float

# %% [markdown]
# Is a print statement required to print a calculation in Google Colab?

# %%
5 + 3
# Out:
# 8

# %% [markdown]
# Are the types of 1 and 2.5 equal to, greater than, or greater than or equal to? Please try each example just to see what is the output.

# %%
print(type(1) == type(21))
# print(type(1) < type(2))
print(type(1) <= type(5))
# Out:
# True
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-1-3551cb3917e3> in <cell line: 3>()
#       1 print(type(1) == type(21))
#       2 # print(type(1) < type(2))
# ----> 3 print(type(1) <= type(5))
#
# TypeError: '<=' not supported between instances of 'type' and 'type'

# %% [markdown]
# Compute 4! using an external library.

# %%
import math
math.factorial(4)
# Out:
# 24

# %% [markdown]
# Round -3.5

# %%
round(-3.5)
# Out:
# -4

# %% [markdown]
# Find Min of -3.5,100,-101,303,-101.25

# %%
min(-3.5, 100, -101, 303, -101.25)
# Out:
# -101.25

# %% [markdown]
# Solve  8÷2(2+2) computationally

# %%
8/2*(2+2)
# Out:
# 16.0

# %% [markdown]
# ###Strings

# %% [markdown]
# Can you slice "hungry" to obtain "un" but only with negative indices? Now try again with one positive index and one negative index.

# %% [markdown]
# Replace any two adjacent characters in "snow". Bonus points if you can spell a new word!

# %% [markdown]
# Split "supercalifragilisticexpialidocious" everytime you see an i, computationally.

# %%
# prompt: Split "supercalifragilisticexpialidocious" everytime you see an i, computationally.

print('supercalifragilisticexpialidocious'.split('i'))
# Out:
# ['supercal', 'frag', 'l', 'st', 'cexp', 'al', 'doc', 'ous']

# %% [markdown]
# Use a string method to convert "HELLO" into lowercase. Hint: Check Python documentation.

# %% [markdown]
# Print "I am Sam. Sam I am." solely using variables and punctuation two different ways using:
# 1.   String Formatting
# 2.   Concatenation
#
# Hint: Initalize three different variables for "I", "am" and "Sam".

# %% [markdown]
# Make the following face using one print statement and escape sequences.
#
#
# ```
# | |
#  <
#  O
# ```

# %% [markdown]
# ###Lists

# %% [markdown]
# Determine how many times 1 appears in [1,4,5,1,3,1,1,4].
#
# Hint: Refer to python documentation and use an existing list method

# %% [markdown]
# Initialize a variable by setting it equal to the following list:
#
# ```
# [1,2,5,6]
# ```
#
# and set that same variable to the above list repeated 9 times.

# %% [markdown]
# Guess the output of the index function when we want to find out what the index of the value 1 is in the following list:
#
# ```
# [3,1,1,2]
# ```
# and then test it out yourself!

# %% [markdown]
# Remove all occurrences of 2's in the following list
# ```
# [2,4,5,6,2]
# ```

# %% [markdown]
# Initialize a list that has the following properties:
#
#
#
# 1.   List has length 4
# 2.   Each element of the list is a list of length 5

# %% [markdown]
# What happens when you cast a list to a string?

# %% [markdown]
# What happens when you cast a string to a list?

# %% [markdown]
# Can you convert
#
#
#
# ```
# ["came", "saw", "conquered"]
# ```
# using join (check Python documentation) to
#
# ```
# "came. I saw. I conquered"
# ```
# and then use string concatentation to write
#
# ```
# "I came. I saw. I conquered."
# ```
# ? Please be careful of spaces and punctuation.

# %% [markdown]
# ###Tuples

# %% [markdown]
# Print the following statment out
#
# ```
# "Hello, I have (3,4,5) blue, green and red socks respectively for a total of 12 socks."
# ```
# except substitute both (3,4,5) and 12 with variables in your print statement. You will need to first initialize separate values for the tuple and the integer. Please get the spacing right!
#
# Hint: If you are running into errors, think about what was thought in this lesson!

# %% [markdown]
# ###Sets

# %% [markdown]
# Get the length of this set: {1,5,7,8}

# %% [markdown]
# Create a set {1,5,7,8}. Add 9 to the set. Pop the last element of the set. What is left in the set?

# %% [markdown]
# Initalize an empty set. Add 5 to the set twice. What is in the set now?

# %% [markdown]
# ###Dictionaries

# %% [markdown]
# Can a tuple be a dictionary key? Can it be a dictionary value?

# %% [markdown]
# Initialize a Dictionary of Dictionaries by mapping integer keys to dictionaries
