# %% [markdown]
# Printing and Commenting

# %%
print("Hello World!") #This prints Hello World!
# Out:
# Hello World!

# %% [markdown]
# Variables

# %%
word = "Hello"
print (word + " World!")
word = "Goodbye"
print (word + " World!")
# Out:
# Hello World!
# Goodbye World!

# %%
carton = 9
carton -= 3
print(carton)
carton += 1.0
print(carton)
type(carton)
# Out:
# 6
# 7.0
# float

# %%
a = 3
b = 4
a+b
# Out:
# 7

# %%
a-b
# Out:
# -1

# %%
a*b
# Out:
# 12

# %%
a/b
# Out:
# 0.75

# %%
a//b
# Out:
# 0

# %%
a%b
# Out:
# 3

# %%
a**b
# Out:
# 81

# %%
abs(-10)
# Out:
# 10

# %%
round(2.5)
# Out:
# 2

# %%
max(3, 2, 8, 9)
# Out:
# 9

# %%
import math

# %%
math.pi
# Out:
# 3.141592653589793

# %%
math.sqrt(4)
# Out:
# 2.0

# %%
from math import sqrt
a = 6
sqrt(a)
# Out:
# 2.449489742783178

# %%
type(2 + 0.6)
# Out:
# float

# %%
type(1) == type(2.5)
# Out:
# False

# %% [markdown]
# Strings

# %%
f = "f"
g = 'g'
print(f + g)
# Out:
# fg

# %%
letters  = "littleiceage"
print(letters[0])
print(letters[-2])
# Out:
# l
# g

# %%
letters[2:5]
# Out:
# 'ttl'

# %%
letters[0:8:3]
# Out:
# 'lti'

# %%
letters[::]
# Out:
# 'littleiceage'

# %%
len(letters)
# Out:
# 12

# %%
print(letters.replace("tt", "c"))
print(letters)
# Out:
# licleiceage
# littleiceage

# %%
frwords = "bonjour:oui:alors"
frwords.split(":")
# Out:
# ['bonjour', 'oui', 'alors']
