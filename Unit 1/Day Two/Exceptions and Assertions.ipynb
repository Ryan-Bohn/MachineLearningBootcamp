# %%
#Syntax error
print("Hi"
# Out:
#   File "<ipython-input-1-225e872d63a3>", line 2
#     print("Hi"
#               ^
# SyntaxError: unexpected EOF while parsing

# %%
#Zero Division Error
5/0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-2-c4ac6d304cdc> in <module>()
#       1 #Zero Division Error
# ----> 2 5/0
#
# ZeroDivisionError: division by zero

# %%
#NameError (Var not defined yet)

thisVar * 3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-1df79e5d8822> in <module>()
#       1 #NameError (Var not defined yet)
#       2
# ----> 3 thisVar * 3
#
# NameError: name 'thisVar' is not defined

# %%
#Type error

print(2.0 + " is cool")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-2bece1cfdfbc> in <module>()
#       1 #Type error
#       2
# ----> 3 print(2.0 + " is cool")
#
# TypeError: unsupported operand type(s) for +: 'float' and 'str'

# %%
try:
  print(2/0)
except ZeroDivisionError:
  print("You got an error")
# Out:
# You got an error

# %%
try:
  print(3/0)
except:
  pass

# %%
a = 9

assert (type(a) == str), "a must be a string"
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-11-8302d728717f> in <module>()
#       1 a = 9
#       2
# ----> 3 assert (type(a) == str), "a must be a string"
#
# AssertionError: a must be a string
