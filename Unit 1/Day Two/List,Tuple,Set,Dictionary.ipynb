# %%
a = "I want {} apples and {} carrots."
apples = 9
print(a.format(apples, 6))
# Out:
# I want 9 apples and 6 carrots.

# %% [markdown]
# Lists:
# ordered, modifiable, indexed

# %%
a = [3, 5, 2, 9]
a.insert(1, "cool")
a
# Out:
# [3, 'cool', 5, 2, 9]

# %%
b = [3, 2]
a + b
# Out:
# [3, 'cool', 5, 2, 9, 3, 2]

# %%
print(a.pop())
a
# Out:
# 5
# [3, 'cool']

# %%
print(a.pop(1))
a
# Out:
# cool
# [3]

# %%
a = [1, 2, 3, 4]
a.remove(2)
a
# Out:
# [1, 3, 4]

# %%
a.reverse()
a
# Out:
# [4, 3, 1]

# %%
b = a.copy()
b.append("last")
print(a)
print(b)

# %% [markdown]
# Tuples: ordered, **immutable**, indexed

# %%
a = (50, "cat", [2, "hi"], 4.2)
a
# Out:
# (50, 'cat', [2, 'hi'], 4.2)

# %%
a = 2
b = 3
c = 8
a, c, a, b
# Out:
# (2, 8, 2, 3)

# %%
#Casting tuple <-> list

a = (50, "cat", [2, "hi"], 4.2)
print(list(a))
# Out:
# [50, 'cat', [2, 'hi'], 4.2]

# %%
b = [50, "cat", [2, "hi"], 4.2]
print(tuple(b))

# %%
#int()
#float()
#str()
#tuple()
#list()

# %% [markdown]
# Sets: unordered, modifiable, unindexed

# %%
a = set()
a
# Out:
# set()

# %%
a = {"Hallo", "Nihau", "Bonjour"}
a.add("Hola")
a
# Out:
# {'Bonjour', 'Hallo', 'Hola', 'Nihau'}

# %%
a = {"Hallo", "Nihau", "Bonjour"}
a.update(["Hi", 45, 4])
a
# Out:
# {4, 45, 'Bonjour', 'Hallo', 'Hi', 'Nihau'}

# %%
a.update("Hey")
a
# Out:
# {4, 45, 'Bonjour', 'H', 'Hallo', 'Hi', 'Nihau', 'e', 'y'}

# %%
a.add(4)
a
# Out:
# {4, 45, 'Bonjour', 'H', 'Hallo', 'Hi', 'Nihau', 'e', 'y'}

# %% [markdown]
# Dictionaries: unordered, modifiable, indexed

# %%
lol = {"blue" : "sky", "orange" : "orange"}
lol
# Out:
# {'blue': 'sky', 'orange': 'orange'}

# %%
lol = {[1, 2, 3] : "hi"}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-38-ff99c2f21565> in <module>()
# ----> 1 lol = {[1, 2, 3] : "hi"}
#
# TypeError: unhashable type: 'list'

# %%
lol = {"hi" : [1, 2, 3]}
lol['hi']
# Out:
# [1, 2, 3]

# %%
lol = {1 : "sky",4: "orange"}
lol[4]
# Out:
# 'orange'

# %%
lol = {"blue" : "sky", "orange" : "orange"}
"blue" in lol
# Out:
# True

# %%
print("orange" in lol, "orange" in lol.values())
# Out:
# True True
