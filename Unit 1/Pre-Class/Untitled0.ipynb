# %%
print("  /////////  \n |  ~   ~  | \n{   * _ *   }\n |    U    | \n |         | \n  \\ \\___/ /  \n   \\_____/   ")
# Out:
#   /////////
#  |  ~   ~  |
# {   * _ *   }
#  |    U    |
#  |         |
#   \ \___/ /
#    \_____/
