# %%
import numpy as np

# %%
a = np.ones(2, 4, 8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-1b432a1f7a4b> in <module>()
# ----> 1 a = np.ones(2, 4, 8)
#
# /usr/local/lib/python3.6/dist-packages/numpy/core/numeric.py in ones(shape, dtype, order)
#     205
#     206     """
# --> 207     a = empty(shape, dtype, order)
#     208     multiarray.copyto(a, 1, casting='unsafe')
#     209     return a
#
# TypeError: data type not understood

# %%
import pandas as pd
df = pd.DataFrame({"A" : [0, 2], "B": [1, 3]})
df
# Out:
#    A  B
# 0  0  1
# 1  2  3

# %%
df.to_numpy()
# Out:
# array([[0, 1],
#        [2, 3]])

# %%
a = np.array([[1, 21, 3], [4, 15, 6], [7, 8, 9]])
a
# Out:
# array([[ 1, 21,  3],
#        [ 4, 15,  6],
#        [ 7,  8,  9]])

# %%
a[1][2]
# Out:
# 6

# %%
a[0:2, 1:3]
# Out:
# array([[21,  3],
#        [15,  6]])

# %%
a = a.T
a
# Out:
# array([[ 1,  4,  7],
#        [21, 15,  8],
#        [ 3,  6,  9]])

# %%
a.flatten()
# Out:
# array([ 1,  4,  7, 21, 15,  8,  3,  6,  9])

# %%
np.sum(a, axis = 0)
# Out:
# array([25, 25, 24])

# %%
np.sum(a)
# Out:
# 74

# %%
np.linalg.det(a)
# Out:
# -6.000000000000029

# %%
b = np.array([[2, 4, 2], [5, 4, 5], [98, 1, 22]])

# %%
a+b
# Out:
# array([[  3,   8,   9],
#        [ 26,  19,  13],
#        [101,   7,  31]])

# %%
a-b
# Out:
# array([[ -1,   0,   5],
#        [ 16,  11,   3],
#        [-95,   5, -13]])

# %%
np.cross(a, b)
# Out:
# array([[ -20,   12,   -4],
#        [  43,  -65,    9],
#        [ 123,  816, -585]])

# %%
a*b #element-wise multiplication, not real matrix multiplication
# Out:
# array([[  2,  16,  14],
#        [105,  60,  40],
#        [294,   6, 198]])

# %%
np.multiply(a, b) #element-wise multiplication, not real matrix multiplication
# Out:
# array([[  2,  16,  14],
#        [105,  60,  40],
#        [294,   6, 198]])

# %%
np.dot(a, b) #true matrix multiplication, as in rows from the first matrix * columns of the second
# Out:
# array([[708,  27, 176],
#        [901, 152, 293],
#        [918,  45, 234]])

# %%
np.zeros((1, 224, 224, 3)) + 3 #broadcasting
# Out:
# array([[[[3., 3., 3.],
#          [3., 3., 3.],
#          [3., 3., 3.],
#          ...,
#          [3., 3., 3.],
#          [3., 3., 3.],
#          [3., 3., 3.]],
#
#         [[3., 3., 3.],
#          [3., 3., 3.],
#          [3., 3., 3.],
#          ...,
#          [3., 3., 3.],
#          [3., 3., 3.],
#          [3., 3., 3.]],
#
#         [[3., 3., 3.],
#          [3., 3., 3.],
#          [3., 3., 3.],
#          ...,
#          [3., 3., 3.],
#          [3., 3., 3.],
#          [3., 3., 3.]],
#
#         ...,
#
#         [[3., 3., 3.],
#          [3., 3., 3.],
#          [3., 3., 3.],
#          ...,
#          [3., 3., 3.],
#          [3., 3., 3.],
#          [3., 3., 3.]],
#
#         [[3., 3., 3.],
#          [3., 3., 3.],
#          [3., 3., 3.],
#          ...,
#          [3., 3., 3.],
#          [3., 3., 3.],
#          [3., 3., 3.]],
#
#         [[3., 3., 3.],
#          [3., 3., 3.],
#          [3., 3., 3.],
#          ...,
#          [3., 3., 3.],
# ...

# %%
a
# Out:
# array([[ 1,  4,  7],
#        [21, 15,  8],
#        [ 3,  6,  9]])

# %%
a + np.array([2, 3, 5]) #This is also Broadcasting
# Out:
# array([[ 3,  7, 12],
#        [23, 18, 13],
#        [ 5,  9, 14]])

# %%
a.ndim
# Out:
# 2

# %%
c = np.ones((3, 4, 2))
c.ndim
# Out:
# 3

# %%
a = np.array([[ 1,  4,  7],
       [21, 15,  8], [4, 0, 43],
       [ 3,  6,  9]])

# %%
a.shape[1] #The feature vectors themselves have dimensions: the number of features (So a row like [34, 0, 1, 5.5] would be a 4 dimensional vector)
# Out:
# 3

# %%
a.shape
# Out:
# (4, 3)

# %%
a.size
# Out:
# 12

# %%
print(np.amin(a))
print(np.amax(a))
# Out:
# 0
# 43

# %%
np.where(a == 4)
# Out:
# (array([0, 2]), array([1, 0]))

# %%
np.save("name.npy", a)

# %%
new_arr = np.load("name.npy")
new_arr
# Out:
# array([[ 1,  4,  7],
#        [21, 15,  8],
#        [ 4,  0, 43],
#        [ 3,  6,  9]])
