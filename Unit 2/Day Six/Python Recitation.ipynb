# %% [markdown]
# **Math Module Functions**

# %% [markdown]
# **Non-Math Module Functions**

# %%
int(4.2)
int(" 5 ")
#int("4.2") Error
#int("Hi") Error
# Out:
# 5

# %% [markdown]
# **range(), randrange()**

# %% [markdown]
# range(initial value def = 0, final value def = len(), interval def = 1)

# %%
x = range(2, 5)
x
# Out:
# range(2, 5)

# %% [markdown]
# randrange(minimum value, maximum value, step

# %%
import random #must import
x = random.randrange(10, 100, 2)
x
# Out:
# 36

# %% [markdown]
# **Strings:** First position is 0, spaces and new lines are characters

# %%
m1 = "Hello Rick and Morty"
m1[4]
# Out:
# 'o'

# %%
m2 = " R y a n \n"
m2 = m2.strip()
m2
# Out:
# 'R y a n'

# %%
m2 = m2.replace(" ", "")
m2
# Out:
# 'Ryan'

# %% [markdown]
# **Defining multiple variables on one line**

# %%
name = "Ryan"
r, y, a, n = name
print(r, y, a, n)
# Out:
# R y a n

# %%
a, b = [4, 2]
a, b = b, a
print(a, b)
# Out:
# 2 4

# %% [markdown]
# **Slicing**

# %%
name = "Billy Rae Cyrus"
sliced_name = name[0:8:2]
sliced_name
# Out:
# 'BlyR'

# %% [markdown]
# **Decision Control Structures**

# %%
x = 3
y = 5
x < y
x > y
x <= y
x >= y
x == y
x != y
# Out:
# True

# %%
print(x < y and x == y)
print(x < y or x == y)
print(not x == y)
# Out:
# False
# True
# True

# %% [markdown]
# **Membership (in)**

# %%
"a" in "Ryan"
# Out:
# True

# %%
3 in [4, 5, 8]
# Out:
# False

# %%
5 in {2 : "a", 5 : "g"}
# Out:
# True

# %% [markdown]
# **If/else**

# %%
hp = int(input("What is the health?"))

if (hp > 6):
  print("danger")
else:
  print("Your safe")
# Out:
# What is the health?12
# danger
