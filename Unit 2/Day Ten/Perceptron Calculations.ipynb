# %%
import numpy as np
theta = np.array([0, 0])
theta_not = 0

# %%
theta += (2, -1)
theta_not += 1
theta, theta_not
# Out:
# (array([ 2, -1]), 1)

# %%
-1 * (theta.T.dot([-1, -3]) + theta_not) <= 0
# Out:
# True

# %%
theta += (-1, -3)
theta_not += -1
theta, theta_not
# Out:
# (array([ 1, -4]), 0)

# %%
-1 * (theta.T.dot([0, 4]) + theta_not) <= 0
# Out:
# False

# %%
1 * (theta.T.dot([2, -1]) + theta_not) <= 0
# Out:
# False

# %%
-1 * (theta.T.dot([-1, -3]) + theta_not) <= 0
# Out:
# True

# %%
theta += (-1, -3)
theta_not += -1
theta, theta_not
# Out:
# (array([ 0, -7]), -1)

# %%
-1 * (theta.T.dot([0, 4]) + theta_not) <= 0
# Out:
# False

# %%
1 * (theta.T.dot([2, -1]) + theta_not) <= 0
# Out:
# False

# %%
-1 * (theta.T.dot([-1, -3]) + theta_not) <= 0
# Out:
# True

# %%
theta += (-1, -3)
theta_not += -1
theta, theta_not
# Out:
# (array([ -1, -10]), -2)

# %%
-1 * (theta.T.dot([0, 4]) + theta_not) <= 0
# Out:
# False

# %%
1 * (theta.T.dot([2, -1]) + theta_not) <= 0
# Out:
# False

# %%
-1 * (theta.T.dot([-1, -3]) + theta_not) <= 0
# Out:
# True

# %%
theta += (-1, -3)
theta_not += -1
theta, theta_not
# Out:
# (array([ -2, -13]), -3)

# %%
-1 * (theta.T.dot([0, 4]) + theta_not) <= 0
# Out:
# False

# %%
1 * (theta.T.dot([2, -1]) + theta_not) <= 0
# Out:
# False

# %%
-1 * (theta.T.dot([-1, -3]) + theta_not) <= 0
# Out:
# True

# %%
theta += (-1, -3)
theta_not += -1
theta, theta_not
# Out:
# (array([ -3, -16]), -4)
